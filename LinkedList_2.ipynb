# %% [markdown]
# <a href="https://colab.research.google.com/github/FarnazG/DataStructure/blob/main/LinkedList_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.  Write a function/method to sort a given linked list with char type node from a-zA-Z. For example, ls = "Head->D->A->C->A->G->NULL", the new linked list should be "Head->A->A->C->D->G->NULL" by calling function srt_LL(ls)

# %%
class Node:

    def __init__(self, data):
        self.data = data  # Assign data
        self.next = None  # Initialize next as null


# Linked List class contains a Node object
class LinkedList:

    def __init__(self):
        self.head = None

    def push(self, new_data):
        new_node = Node(new_data)
        new_node.next = self.head
        self.head = new_node


    def append(self, new_data):
        new_node = Node(new_data)
        if self.head is None:
            self.head = new_node
            return

        last = self.head
        while (last.next):
            last = last.next

        last.next = new_node

    def printList(self):
        temp = self.head
        while (temp):
            print(temp.data, end=' ')
            temp = temp.next
        print("")

    def srt_LL(self):
        if self.head is None:
            return

        h1 = self.head

        while h1:
            h2 = h1.next
            while h2:
                if ord(h2.data) < ord(h1.data):
                    tmp = h1.data
                    h1.data = h2.data
                    h2.data = tmp
                h2 = h2.next
            h1 = h1.next


lst = LinkedList()
lst.append('D')
lst.append('A')
lst.append('C')
lst.append('A')
lst.append('G')
lst.printList()
lst.srt_LL()
lst.printList()
# Out:
# D A C A G
# A A C D G

# %% [markdown]
# 2.  Assuming that there are two linked lists with positive number type value in each node, such as u= "Head->1->2->3->4->NULL" and v="Head->5->6->7->8->NULL", two numbers 1234 & 5678 from the linked lists can be extracted respectively, and make addition operation for two numbers, the result will be 6912(=1234+5678) . Find a function/method to implement above operations and get such result "Head->6->9->1->2->NULL" if calling function LL_add(u,v)

# %%
class Node:

    def __init__(self, data):
        self.data = data  # Assign data
        self.next = None  # Initialize next as null


# Linked List class contains a Node object
class LinkedList:

    def __init__(self):
        self.head = None

    def push(self, new_data):
        new_node = Node(new_data)
        new_node.next = self.head
        self.head = new_node


    def append(self, new_data):
        new_node = Node(new_data)
        if self.head is None:
            self.head = new_node
            return

        last = self.head
        while (last.next):
            last = last.next

        last.next = new_node

    def printList(self):
        temp = self.head
        while (temp):
            print(temp.data, end=' ')
            temp = temp.next
        print("")


def LL_add(u, v):

    hu = u.head
    un = 0
    while hu:
        un = 10 * un + hu.data
        hu = hu.next

    hv = v.head
    vn = 0
    while hv:
        vn = 10 * vn + hv.data
        hv = hv.next

    on = un + vn

    output = LinkedList()
    oh = output.head

    while on > 0:
        output.push(on % 10)
        on = int(on / 10)

    return output


lst1 = LinkedList()
lst1.append(1)
lst1.append(2)
lst1.append(3)
lst1.append(4)
lst1.printList()

lst2 = LinkedList()
lst2.append(5)
lst2.append(6)
lst2.append(7)
lst2.append(8)
lst2.printList()

output = LL_add(lst1, lst2)
print("----------")
output.printList()
# Out:
# 1 2 3 4
# 5 6 7 8
# ----------
# 6 9 1 2

# %% [markdown]
# 3. Solve monkey king election question on the handout by circular linked list in a programInput Enter total number of monkeys in a group: 5 Enter m value: 3       Output The king will be 3       Input Enter total number of monkeys in a group: 8 Enter m value: 5      Output The king will be 2 Notice that 1st monkey’s label should start with 0 as an index

# %%
class Node:

    def __init__(self, data):
        self.data = data  # Assign data
        self.next = None  # Initialize next as null


# Linked List class contains a Node object
class LinkedList:

    def __init__(self):
        self.head = None

    def push(self, new_data):
        new_node = Node(new_data)
        new_node.next = self.head
        self.head = new_node

    def remove(self, elem):
        h = self.head
        if h == elem:
            self.head = self.head.next
            return

        while h.next:
            if h.next == elem:
                h.next = h.next.next
                return
            h = h.next


    def append(self, new_data):
        new_node = Node(new_data)
        if self.head is None:
            self.head = new_node
            return

        last = self.head
        while (last.next):
            last = last.next

        last.next = new_node

    def printList(self, n):
        temp = self.head
        #while (temp):
        for i in range(0,n):
            print(temp.data, end=' ')
            temp = temp.next
        print("")


def monkeyKing(LL, n, m):
    h = LL.head

    for c in range(0, n-1):
        for i in range(0, m-1):
            h = h.next
            while h.data == -1:
                h = h.next
        #LL.printList(n)

        h.data = -1
        while h.data == -1:
            h = h.next

    return h.data

lst1 = LinkedList()
n = int(input("Enter total number of monkeys in a group: "))
m = int(input("Enter m value: "))

for i in range(0, n):
    lst1.append(i)

h = lst1.head
while h.next:
    h = h.next

h.next = lst1.head

print("The king will be " + str(monkeyKing(lst1, n, m)))
# Out:
# Enter total number of monkeys in a group: 8
# Enter m value: 5
# The king will be 2

# %% [markdown]
# 4. Given two singly linked lists with char type value node, like a-zA-Zl= "Head->G->O->O->D->NULL", and m ="Head->G->o->O->g->L->E->NULL", Find the common char values and form a new linked list "Head->G->O->NULL" through a function/method calledcommElem(l, m).

# %%
class Node:

    def __init__(self, data):
        self.data = data  # Assign data
        self.next = None  # Initialize next as null


# Linked List class contains a Node object
class LinkedList:

    def __init__(self):
        self.head = None

    def push(self, new_data):
        new_node = Node(new_data)
        new_node.next = self.head
        self.head = new_node

    def remove(self, elem):
        h = self.head
        if h == elem:
            self.head = self.head.next
            return

        while h.next:
            if h.next == elem:
                h.next = h.next.next
                return
            h = h.next


    def append(self, new_data):
        new_node = Node(new_data)
        if self.head is None:
            self.head = new_node
            return

        last = self.head
        while (last.next):
            last = last.next

        last.next = new_node

    def printList(self):
        temp = self.head
        while (temp):
            print(temp.data, end=' ')
            temp = temp.next
        print("")


def commElem(u, v):
    output = LinkedList()
    hu = u.head

    while hu:
        hv = v.head
        while hv:
            if hv.data == hu.data:
                output.append(hv.data)
                v.remove(hv)
                break
            hv = hv.next
        hu = hu.next

    return output


lst1 = LinkedList()
lst1.append('G')
lst1.append('O')
lst1.append('O')
lst1.append('D')
lst1.printList()

lst2 = LinkedList()
lst2.append('G')
lst2.append('o')
lst2.append('O')
lst2.append('g')
lst2.append('L')
lst2.append('E')
lst2.printList()

output = commElem(lst1, lst2)
output.printList()
# Out:
# G O O D
# G o O g L E
# G O

# %% [markdown]
# 5. Write a function diffElem_LL(l, m)as similar as above, but to exact all char values, which are NOT common ones, and link them together, such as "Head->D->o->g->L->E->NULL",

# %%
class Node:

    def __init__(self, data):
        self.data = data  # Assign data
        self.next = None  # Initialize next as null


# Linked List class contains a Node object
class LinkedList:

    def __init__(self):
        self.head = None

    def push(self, new_data):
        new_node = Node(new_data)
        new_node.next = self.head
        self.head = new_node

    def remove(self, elem):
        h = self.head
        if h == elem:
            self.head = self.head.next
            return

        while h.next:
            if h.next == elem:
                h.next = h.next.next
                return
            h = h.next


    def append(self, new_data):
        new_node = Node(new_data)
        if self.head is None:
            self.head = new_node
            return

        last = self.head
        while (last.next):
            last = last.next

        last.next = new_node

    def printList(self):
        temp = self.head
        while (temp):
            print(temp.data, end=' ')
            temp = temp.next
        print("")


def repeat(u,v):
    output = LinkedList()
    lstu = []
    hu = u.head
    while hu:
        lstu.append(0)
        hv = v.head
        while hv:
            if hv.data == hu.data:
                lstu[len(lstu) - 1] += 1
            hv = hv.next
        hu = hu.next

    hu = u.head
    c = 0
    while hu:
        if lstu[c] == 0:
            output.append(hu.data)
        hu = hu.next
        c += 1

    return output


def diffElem_LL(u, v):
    out1 = repeat(u, v)
    out2 = repeat(v, u)

    h2 = out2.head
    while h2:
        out1.append(h2.data)
        h2 = h2.next

    return out1


lst1 = LinkedList()
lst1.append('G')
lst1.append('O')
lst1.append('O')
lst1.append('D')
lst1.printList()

lst2 = LinkedList()
lst2.append('G')
lst2.append('o')
lst2.append('O')
lst2.append('g')
lst2.append('L')
lst2.append('E')
lst2.printList()

output = diffElem_LL(lst1, lst2)
output.printList()
# Out:
# G O O D
# G o O g L E
# D o g L E

# %% [markdown]
# 6. Given a linked list, write a program to check if there exists an internal linked loop or not. For instance, as following, return value of function/method is_loopLL(a) is true, otherwise false.Notice that there is ONLY one link to next in node structure

# %%
class Node:

    def __init__(self, data):
        self.data = data  # Assign data
        self.next = None  # Initialize next as null


# Linked List class contains a Node object
class LinkedList:

    def __init__(self):
        self.head = None

    def push(self, new_data):
        new_node = Node(new_data)
        new_node.next = self.head
        self.head = new_node

    def remove(self, elem):
        h = self.head
        if h == elem:
            self.head = self.head.next
            return

        while h.next:
            if h.next == elem:
                h.next = h.next.next
                return
            h = h.next


    def append(self, new_data):
        new_node = Node(new_data)
        if self.head is None:
            self.head = new_node
            return

        last = self.head
        while (last.next):
            last = last.next

        last.next = new_node

    def printList(self):
        temp = self.head
        while (temp):
            print(temp.data, end=' ')
            temp = temp.next
        print("")

    def is_loopLL(self):
        h1 = self.head
        h2 = self.head

        while h1 and h2 and h2.next:
            h1 = h1.next
            h2 = h2.next.next
            if h1 == h2:
                return True
        return False



lst1 = LinkedList()
lst1.append('G')
lst1.append('O')
lst1.append('O')
lst1.append('D')
lst1.head.next.next.next.next = lst1.head.next.next
if lst1.is_loopLL():
    print("There is a loop")
else:
    print("No loop")

lst2 = LinkedList()
lst2.append('G')
lst2.append('o')
lst2.append('O')
lst2.append('g')
lst2.append('L')
lst2.append('E')
if lst2.is_loopLL():
    print("There is a loop")
else:
    print("No loop")
# Out:
# There is a loop
# No loop
